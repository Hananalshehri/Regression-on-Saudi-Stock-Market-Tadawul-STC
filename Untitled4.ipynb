# %%
import requests
from bs4 import BeautifulSoup
import csv
from itertools import zip_longest

# %% [markdown]
# # Using requests to fetch the url

# %%
result= requests.get('https://ereference.tadawul.com.sa/ir/historicaldata/list.xhtml')

# %% [markdown]
# # Save page content

# %%
src= result.content
print(src)
# Out:
# b'<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" lang="en" xml:lang="en" dir="ltr"><head>\n\t<title>Tadawul</title>\n\t<link rel="shortcut icon" href="/irresources/faviconEref.ico" />\n\t<meta charset="utf-8" />\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n\n\t<script type="text/javascript">\n\t\tvar resourceDirectoryPath = \'/irresources\';\n\t</script>\n\t\t<link href="/irresources/css/tcal.css" media="screen" rel="stylesheet" type="text/css" />\n\t\t<!-- &lt;link rel=&quot;stylesheet&quot; type=&quot;text/css&quot; media=&quot;screen&quot; href=&quot;/irresources/css/bootstrap.css&quot; /&gt; -->\n\n\t\t<link rel="stylesheet" type="text/css" media="screen" href="/irresources/css/bootstrap-extra.css" />\n\t\t<link rel="stylesheet" type="text/css" media="screen" href="/irresources/css/master.css" />\n\t\t<link rel="stylesheet" type="text/css" media="screen" href="/irresources/css/checkbox-radio.css" />\n\t\t<link rel="stylesheet" type="text/css" media="sc
# ...

# %%
soup = BeautifulSoup(src,"lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml"><head>
# <title>Tadawul</title>
# <link href="/irresources/faviconEref.ico" rel="shortcut icon"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <script type="text/javascript">
# 		var resourceDirectoryPath = '/irresources';
# 	</script>
# <link href="/irresources/css/tcal.css" media="screen" rel="stylesheet" type="text/css"/>
# <!-- &lt;link rel=&quot;stylesheet&quot; type=&quot;text/css&quot; media=&quot;screen&quot; href=&quot;/irresources/css/bootstrap.css&quot; /&gt; -->
# <link href="/irresources/css/bootstrap-extra.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/irresources/css/master.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/irresources/css/checkbox-radio.css" media="screen" rel="stylesheet" type="text/css"/>
# ...

# %%
Company_name []
High []
Low []
Date []
